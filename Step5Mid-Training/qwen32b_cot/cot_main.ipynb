# %%
import os
import json
from openai import OpenAI


COT_PROMPT = """
作为助理，您的职责是深入探究问题，并经过系统而详尽的思考，最终提供精准的解决方案。
这需要您进行全面的分析、总结、探索、重新评估、反思、回溯和迭代，以形成深思熟虑的思维过程。
请将您的回答分为两个主要部分：思考过程和解决方案。

在“思考过程”部分，请使用以下格式详细描述您的推理过程：<begin_of_thought>{思考过程，步骤之间用“\n\n”分隔} <end_of_thought> 每个步骤都应包含详细的思考过程，例如分析问题、总结相关发现、集思广益提出新想法、验证当前步骤的准确性、修正错误以及回顾之前的步骤。
在“解决方案”部分，基于“思考过程”部分中的各种尝试、探索和反思，系统地呈现您认为正确的最终解决方案。解决方案应保持逻辑清晰、准确简洁的表达风格，并详细说明得出结论所需的必要步骤，格式如下：<begin_of_solution> {最终格式化、精确且清晰的解决方案} <end_of_solution> 

现在，请尝试根据以上指导原则解决以下问题："
"""

llm_client = OpenAI(
    api_key="EMPTY",
    base_url="http://localhost:8000/v1"
)

def request_chat(query):

    try:
        prompt = COT_PROMPT + query
    
        completion = llm_client.chat.completions.create(
            model="Qwen32B",
            messages=[
                {"role": "user", "content": prompt}
            ],
            max_tokens=4096,
            temperature=0.6,
            top_p=0.95
        )
        result = completion.choices[0].message.content
        return query, result
        
    except:
        return query, ""

# %% [markdown]
# # 调用Qwen32B本地模型

# %%
# 测试 1
query = "大瓶芒果汁容量为30盎司，每瓶售价2700比塞塔。小瓶容量为6盎司，每瓶售价600比塞塔。购买一大瓶而不是同样体积的小瓶可以节省多少比塞塔？"
_, res = request_chat(query)
print(res)
# Out:
# <begin_of_thought>
# 为了计算节省的金额，首先需要明确购买相同体积的果汁时，大瓶和小瓶的价格差异。
#
# 1. 确定大瓶和小瓶的容量和价格：
#    - 大瓶容量为30盎司，售价为2700比塞塔。
#    - 小瓶容量为6盎司，售价为600比塞塔。
#
# 2. 计算购买等同于一大瓶（30盎司）容量的小瓶数量：
#    - 一大瓶的容量为30盎司，因此需要5个小瓶才能达到相同的容量（因为30除以6等于5）。
#
# 3. 计算购买5个小瓶的总费用：
#    - 如果一个小瓶的价格是600比塞塔，那么5个小瓶的价格就是600乘以5，即3000比塞塔。
#
# 4. 对比购买大瓶与购买等量小瓶的成本差额：
#    - 大瓶的价格为2700比塞塔，而5个小瓶的总价为3000比塞塔。
#    - 因此，节省的金额为3000比塞塔减去2700比塞塔，等于300比塞塔。
# <end_of_thought>
#
# <begin_of_solution>
# 购买一大瓶芒果汁而非同样体积的小瓶可以节省300比塞塔。这一结论基于以下步骤：确定了大瓶和小瓶的容量与价格，计算出购买与一大瓶容量相等的小瓶数量及其总成本，最后通过对比两种购买方式的成本得出节省的金额。 <end_of_solution>

# %%
# 测试 2
query = "证明：如果A和B是两个n阶方阵，且AB=BA，那么tr(AB)=tr(BA)。"
_, res = request_chat(query)
print(res)
# Out:
# <begin_of_thought>
# 1. 首先，明确题目要求证明的等式：tr(AB) = tr(BA)，其中tr表示矩阵的迹，即矩阵主对角线上元素之和。
# 2. 由于A和B都是n阶方阵，我们可以利用矩阵乘法的定义和迹的性质进行证明。
# 3. 矩阵乘法AB的(i,j)位置上的元素由A的第i行与B的第j列对应元素相乘后求和得到。因此，AB的迹是由A的第i行与B的第i列对应元素相乘后的和组成的总和。
# 4. 同理，BA的迹也可以通过类似的方式计算，它是B的第i行与A的第i列对应元素相乘后的和组成的总和。
# 5. 根据题设条件AB=BA，我们直接知道这两个矩阵是相等的，这意味着它们对应的元素也是相等的。
# 6. 因此，AB和BA的迹实际上是相同的元素组合，只是排列顺序可能不同而已。
# 7. 由于迹的值只依赖于主对角线上的元素，而这些元素在AB和BA中是相同的（因为AB=BA），所以tr(AB)和tr(BA)的值必然相同。
# 8. 综上所述，我们可以通过矩阵乘法和迹的定义来证明tr(AB)=tr(BA)。
# </begin_of_thought>
#
# <begin_of_solution>
# 为了证明tr(AB) = tr(BA)，其中A和B是两个n阶方阵且满足AB=BA，我们可以按照以下步骤进行：
#
# 1. 记住矩阵的迹定义为矩阵主对角线上的元素之和，即对于n阶方阵X，其迹tr(X)可以表示为\(\sum_{i=1}^{n} X_{ii}\)。
# 2. 利用矩阵乘法的定义，AB的(i,i)位置上的元素是A的第i行与B的第i列对应元素相乘后的和；同理，BA的(i,i)位置上的元素是B的第i行与A的第i列对应元素相乘后的和。
# 3. 因为AB=BA，所以对于所有i，有\( (AB)_{ii} = (BA)_{ii} \)。
# 4. 由此可知，AB和BA的主对角线上的元素是相同的，即对于所有的i，\(A_iB_i = B_iA_i\)，其中\(A_i\)和\(B_i\)分别代表A的第i行和B的第i列。
# 5. 所以，tr(AB) = \(\sum_{i=1}^{n} (AB)_{ii} = \sum_{i=1}^{n} (BA)_{ii} = tr(BA)\)。
#
# ...

# %%
# 测试 3
query = "写一篇小红书风格的帖子，300字以内，标题是🍑科颜氏男士护肤系列使用心得"
_, res = request_chat(query)
print(res)
# Out:
# <begin_of_thought>
# 1. 分析题目要求：需要撰写一篇符合小红书风格的帖子，主题为科颜氏男士护肤系列的使用心得，字数限制在300字以内。
# 2. 思考目标受众：男性护肤品用户，特别是对品牌有好奇心或需求的消费者。
# 3. 确定内容结构：开头吸引注意，中间分享使用体验，结尾给出推荐。
# 4. 搜集相关信息：科颜氏男士护肤系列的特点，如成分、效果等。
# 5. 设计吸引人的标题和开头，确保能够抓住读者的兴趣。
# 6. 详细描述使用感受，包括产品的实际效果，与预期是否相符。
# 7. 总结产品优缺点，给出明确的个人评价和建议。
# 8. 编辑语言，使其更符合小红书的轻松活泼风格。
# <end_of_thought>
#
# <begin_of_solution>
# 标题：🍑科颜氏男士护肤系列使用心得
#
# ✨终于找到了适合自己的护肤秘籍！自从用了科颜氏男士护肤系列，我的皮肤状态大变样！🌿
#
# 首先，它的洁面泡沫超级温和，清洁力强但不刺激，每天早晚用一次，感觉毛孔都清爽了。🧴
#
# 然后是爽肤水，质地轻薄，吸收快，用后皮肤水润不油腻，特别适合我这种油性肌肤。💧
#
# 最后说说面霜，虽然我是油皮，但也需要保湿哦！这款面霜控油的同时还能锁住水分，整天下来都不觉得紧绷。💦
#
# 总体来说，科颜氏男士护肤系列性价比高，效果明显，强烈推荐给所有追求自然健康的男生们！💪
#
# #科颜氏男士护肤 #男士护肤心得 #护肤必备
# <end_of_solution>

# %%
import re

pattern = r'<begin_of_thought>(.*?)<end_of_thought>'
reasoning = re.findall(pattern, res, re.DOTALL)
print("==== 思考的内容 ====")
print(reasoning[0])

pattern = r'<begin_of_solution>(.*?)<end_of_solution>'
answer = re.findall(pattern, res, re.DOTALL)
print("==== 答案 ====")
print(answer[0])
# Out:
# ==== 思考的内容 ====
#
# 1. 分析题目要求：需要撰写一篇符合小红书风格的帖子，主题为科颜氏男士护肤系列的使用心得，字数限制在300字以内。
# 2. 思考目标受众：男性护肤品用户，特别是对品牌有好奇心或需求的消费者。
# 3. 确定内容结构：开头吸引注意，中间分享使用体验，结尾给出推荐。
# 4. 搜集相关信息：科颜氏男士护肤系列的特点，如成分、效果等。
# 5. 设计吸引人的标题和开头，确保能够抓住读者的兴趣。
# 6. 详细描述使用感受，包括产品的实际效果，与预期是否相符。
# 7. 总结产品优缺点，给出明确的个人评价和建议。
# 8. 编辑语言，使其更符合小红书的轻松活泼风格。
#
# ==== 答案 ====
#
# 标题：🍑科颜氏男士护肤系列使用心得
#
# ✨终于找到了适合自己的护肤秘籍！自从用了科颜氏男士护肤系列，我的皮肤状态大变样！🌿
#
# 首先，它的洁面泡沫超级温和，清洁力强但不刺激，每天早晚用一次，感觉毛孔都清爽了。🧴
#
# 然后是爽肤水，质地轻薄，吸收快，用后皮肤水润不油腻，特别适合我这种油性肌肤。💧
#
# 最后说说面霜，虽然我是油皮，但也需要保湿哦！这款面霜控油的同时还能锁住水分，整天下来都不觉得紧绷。💦
#
# 总体来说，科颜氏男士护肤系列性价比高，效果明显，强烈推荐给所有追求自然健康的男生们！💪
#
# #科颜氏男士护肤 #男士护肤心得 #护肤必备

# %%
import json
from tqdm import tqdm
from concurrent.futures import ProcessPoolExecutor, as_completed 

max_workers = 64

fd = open("./data/liucong/Chinese-DeepSeek-R1-Distill-data-110k/distill_r1_110k.jsonl")
inputs = []
for line in fd:
    inputs.append(json.loads(line)["input"])

# 测试128条
inputs = inputs[:128]

# 使用多进程生成 COT Reasoning PATH
with ProcessPoolExecutor(max_workers=max_workers) as executor:
    futures = [executor.submit(request_chat, query) for query in inputs]
    for future in tqdm(as_completed(futures), total=len(inputs), desc="COT Generations"):
        query, cot_res = future.result()
        if cot_res:
            # write to file...
            pass
# Out:
# ...
# COT Generations: 100%|██████████| 128/128 [01:20<00:00,  1.60it/s]
