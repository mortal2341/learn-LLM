# %%
import pyarrow.parquet as pq

# %%
table = pq.read_table("raw_data/code_math/train-00000-of-00015.parquet")
data = table.to_pydict()

# %%
data.keys()
# Out:
# dict_keys(['id', 'conversations', 'label', 'langdetect', 'source', 'reward'])

# %%
data["conversations"][0]
# Out:
# [{'from': 'human',
#   'value': 'I need to create a program that stops a specific service called "SageTV" on a Windows operating system. I want to do this programmatically using a command-line interface or a script. How can I achieve this using a programming language like Python?'},
#  {'from': 'gpt',
#   'value': 'You can use the `subprocess` module in Python to achieve this task. Here\'s an example of how you can stop the "SageTV" service using Python:\n\n```python\nimport subprocess\n\n# Command to stop the SageTV service\ncommand = "net stop SageTV"\n\n# Execute the command using subprocess\nsubprocess.run(command, shell=True)\n```\n\nThe `subprocess.run` function allows you to run the specified command in the shell. By passing `shell=True`, you can execute the command as if it were run in the command prompt. This will effectively stop the SageTV service on the Windows system.'}]

# %%
data["conversations"][100]
# Out:
# [{'from': 'human',
#   'value': 'In an election between two candidates A and B, the number of valid votes received by A exceeds those received by B by 15% of the total number of votes polled. A certain percentage of the votes polled were invalid and a total of 5720 votes were polled. B got 1859 valid votes. What is the percentage of invalid votes?'},
#  {'from': 'gpt',
# ...

# %%
data["conversations"][-1]
# Out:
# [{'from': 'human',
#   'value': 'Two congruent cones with radius 12 cm and height 12 cm are enclosed within a cylinder. The base of each cone is a base of the cylinder, and the height of the cylinder is 24 cm. What is the number of cubic centimeters in the volume of the cylinder not occupied by the cones? Express your answer in terms of $\\pi$.'},
#  {'from': 'gpt',
#   'value': 'The volume of each cone is $\\frac{1}{3} \\pi r^2 h = \\frac{1}{3} \\pi (12^2)(12) = 576 \\pi$ cubic cm.\nThe combined volume of the two cones is $2 \\cdot 576 \\pi = 1152 \\pi$ cubic cm.\nThe volume of the cylinder is $\\pi r^2 h = \\pi (12^2)(24) = 3456 \\pi$ cubic cm.\nThe volume not occupied by the cones is the volume of the cylinder minus the volume of the cones, which is $3456 \\pi - 1152 \\pi = \\boxed{2304 \\pi}$ cubic cm.The answer is: 2304\\pi'}]

# %%
table = pq.read_table("raw_data/text_books/00000.parquet")
data = table.to_pydict()

# %%
data.keys()
# Out:
# dict_keys(['text', 'score', 'source', 'data_format'])

# %%
data["text"][0]
# Out:
# '### 教程：如何培养和展现蜂目豺声的特质\n\n#### 教程目的\n\n本教程旨在帮助您理解和培养“蜂目豺声”这一特质，使其成为个人魅力的一部分。通过本教程，您将学会如何改变自己的外观和声音，以展现出这种凶恶而又可怕的形象。请记住，这样的形象在现实生活中可能并不适用，但在特定的表演、角色扮演或个人兴趣中，它可能是一个有趣的挑战。\n\n#### 所需材料\n\n1. **镜子**\n2. **录音设备**\n3. **面妆材料（可选）**\n\n#### 第一步：分析蜂目豺声的外貌特征\n\n**目的：** 了解“蜂目豺声”的外貌特征，以便进行模仿和调整。\n\n1. **眼睛：** 蜂目通常指的是眼睛小而锐利，有凶光。\n2. **声音：** 豺声则是指低沉、沙哑、有威胁性的声音。\n\n**深入解释：**\n- **眼睛特征：** 通过镜子观察自己的眼睛，思考如何让它们显得更加锐利和有神。这可以通过改变眼神、锻炼眼部肌肉或使用适当的化妆技术来实现。\n- **声音特征：** 了解声音的音调和节奏对整体形象的影响。练习降低音调、加快语速和增加语气强度，以模仿豺声。\n\n#### 第二步：调整眼神\n\n**目的：** 通过调整眼神，使其看起来更加锐利和有威胁。\n\n1. **眼神练习：**\n   - **坚持练习：** 每天花一些时间练习眼神。尝试盯着一个固定点，然后缓慢地移动视线，保持眼神锐利。\n   - **模仿：** 观看电影或视频中具有蜂目特质的人物，仔细观察他们的眼神，并尝试模仿。\n\n2. **化妆技巧（可选）：**\n   - **使用眼线：** 在眼角处使用深色的眼线，可以突出眼睛的锐利感。\n   - **强调眼影：** 使用深色眼影在眼角处加深，模仿蜂眼的轮廓。\n\n**深入解释：**\n- **锻炼眼部肌肉：** 长时间的眼神练习有助于锻炼眼部肌肉，使眼神更加有神。\n- **化妆增强：** 化妆可以是一种临时手段，帮助您快速展现出蜂目的效果。\n\n#### 第三步：调整声音\n\n**目的：** 通过练习声音的音调和节奏，使其听起来更加低沉、沙哑和威胁性。\n\n1. **声音练习：**\n   - **降低音调：** 练习深呼吸，以增加声带的张力，从而使声音更低沉。\n   - **加快语速：** 练习快速说话，但
# ...
